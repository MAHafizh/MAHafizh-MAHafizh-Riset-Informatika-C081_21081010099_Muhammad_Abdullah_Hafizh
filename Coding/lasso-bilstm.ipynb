# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.losses import MeanSquaredError 
from tensorflow.keras.metrics import RootMeanSquaredError 
from tensorflow.keras.optimizers import Adam 

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso

from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('KURS IDRUSD 20132023.csv', sep=';')
df
# Out:
#             date  kurs_close  value_import  value_export  volume_import  \
# 0     2015-01-01       12385           143           150         147093
# 1     2015-01-02       12543           143           150         147093
# 2     2015-01-05       12628           143           150         147093
# 3     2015-01-06       12658           143           150         147093
# 4     2015-01-07       12739           143           150         147093
# ...          ...         ...           ...           ...            ...
# 2287  2023-12-25       15467           222           259         197971
# 2288  2023-12-26       15407           222           259         197971
# 2289  2023-12-27       15425           222           259         197971
# 2290  2023-12-28       15415           222           259         197971
# 2291  2023-12-29       15395           222           259         197971
#
#       volume_export
# 0            508827
# 1            508827
# 2            508827
# 3            508827
# 4            508827
# ...             ...
# 2287         701798
# 2288         701798
# 2289         701798
# 2290         701798
# 2291         701798
#
# [2292 rows x 6 columns]

# %%
df['value_import'] = df['value_import'] * 1_000_000
df['value_export'] = df['value_export'] * 1_000_000

# %%
df
# Out:
#             date  kurs_close  value_import  value_export  volume_import  \
# 0     2015-01-01       12385     143000000     150000000         147093
# 1     2015-01-02       12543     143000000     150000000         147093
# 2     2015-01-05       12628     143000000     150000000         147093
# 3     2015-01-06       12658     143000000     150000000         147093
# 4     2015-01-07       12739     143000000     150000000         147093
# ...          ...         ...           ...           ...            ...
# 2287  2023-12-25       15467     222000000     259000000         197971
# 2288  2023-12-26       15407     222000000     259000000         197971
# 2289  2023-12-27       15425     222000000     259000000         197971
# 2290  2023-12-28       15415     222000000     259000000         197971
# 2291  2023-12-29       15395     222000000     259000000         197971
#
#       volume_export
# 0            508827
# 1            508827
# 2            508827
# 3            508827
# 4            508827
# ...             ...
# 2287         701798
# 2288         701798
# 2289         701798
# 2290         701798
# 2291         701798
#
# [2292 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2292 non-null   object
#  1   kurs_close     2292 non-null   int64
#  2   value_import   2292 non-null   int64
#  3   value_export   2292 non-null   int64
#  4   volume_import  2292 non-null   int64
#  5   volume_export  2292 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 107.6+ KB

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2292 non-null   datetime64[ns]
#  1   kurs_close     2292 non-null   int64
#  2   value_import   2292 non-null   int64
#  3   value_export   2292 non-null   int64
#  4   volume_import  2292 non-null   int64
#  5   volume_export  2292 non-null   int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 107.6 KB

# %%
df.corr()["kurs_close"].sort_values(ascending=False)
# Out:
# kurs_close       1.000000
# date             0.825484
# volume_export    0.762829
# volume_import    0.690961
# value_import     0.684193
# value_export     0.680033
# Name: kurs_close, dtype: float64

# %%
df.set_index('date', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2292 entries, 2015-01-01 to 2023-12-29
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kurs_close     2292 non-null   int64
#  1   value_import   2292 non-null   int64
#  2   value_export   2292 non-null   int64
#  3   volume_import  2292 non-null   int64
#  4   volume_export  2292 non-null   int64
# dtypes: int64(5)
# memory usage: 107.4 KB

# %%
df
# Out:
#             kurs_close  value_import  value_export  volume_import  \
# date
# 2015-01-01       12385     143000000     150000000         147093
# 2015-01-02       12543     143000000     150000000         147093
# 2015-01-05       12628     143000000     150000000         147093
# 2015-01-06       12658     143000000     150000000         147093
# 2015-01-07       12739     143000000     150000000         147093
# ...                ...           ...           ...            ...
# 2023-12-25       15467     222000000     259000000         197971
# 2023-12-26       15407     222000000     259000000         197971
# 2023-12-27       15425     222000000     259000000         197971
# 2023-12-28       15415     222000000     259000000         197971
# 2023-12-29       15395     222000000     259000000         197971
#
#             volume_export
# date
# 2015-01-01         508827
# 2015-01-02         508827
# 2015-01-05         508827
# 2015-01-06         508827
# 2015-01-07         508827
# ...                   ...
# 2023-12-25         701798
# 2023-12-26         701798
# 2023-12-27         701798
# 2023-12-28         701798
# 2023-12-29         701798
#
# [2292 rows x 5 columns]

# %%
x = df[['value_import', 'value_export', 'volume_import', 'volume_export']]
y = df['kurs_close']

# %%
x.shape, y.shape
# Out:
# ((2292, 4), (2292,))

# %%
x_train, x_test, y_train, x_train = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, y_train.shape
# Out:
# ((459,), (1833,))

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 lasso = Lasso(alpha=0.1)
# ----> 2 lasso.fit(x_train, y_train)
#
# File c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:980, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#     978 if check_input:
#     979     X_copied = self.copy_X and self.fit_intercept
# --> 980     X, y = self._validate_data(
#     981         X,
#     982         y,
#     983         accept_sparse="csc",
#     984         order="F",
#     985         dtype=[np.float64, np.float32],
#     986         force_writeable=True,
#     987         accept_large_sparse=False,
#     988         copy=X_copied,
#     989         multi_output=True,
#     990         y_numeric=True,
#     991     )
#     992     y = check_array(
#     993         y, order="F", copy=False, dtype=X.dtype.type, ensure_2d=False
#     994     )
#     996 n_samples, n_features = X.shape
#
# File c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\sklearn\utils\validation.py:1050, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043         else:
#    1044             msg = (
#    1045                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1046                 "Reshape your data either using array.reshape(-1, 1) if "
#    1047                 "your data has a single feature or array.reshape(1, -1) "
#    1048                 "if it contains a single sample."
#    1049             )
# -> 1050         raise ValueError(msg)
#    1052 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1053     raise ValueError(
#    1054         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1055         "Convert your data to numeric values explicitly instead."
#    1056     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.core.series.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

# %%
scaler = StandardScaler()
scaler_values = scaler.fit_transform(df[df.columns])

# %%
scaler_values
# Out:
# array([[-2.31750268, -0.98364478, -0.90502858, -1.26350601, -1.39985518],
#        [-2.10871166, -0.98364478, -0.90502858, -1.26350601, -1.39985518],
#        [-1.99638738, -0.98364478, -0.90502858, -1.26350601, -1.39985518],
#        ...,
#        [ 1.69974219,  1.33078044,  1.313349  ,  1.94931893,  1.66544108],
#        [ 1.68652757,  1.33078044,  1.313349  ,  1.94931893,  1.66544108],
#        [ 1.66009833,  1.33078044,  1.313349  ,  1.94931893,  1.66544108]])

# %%
df_scaled = pd.DataFrame(scaler_values, columns = df.columns, index = df.index)

# %%
df_scaled
# Out:
#             kurs_close  value_import  value_export  volume_import  \
# date
# 2015-01-01   -2.317503     -0.983645     -0.905029      -1.263506
# 2015-01-02   -2.108712     -0.983645     -0.905029      -1.263506
# 2015-01-05   -1.996387     -0.983645     -0.905029      -1.263506
# 2015-01-06   -1.956744     -0.983645     -0.905029      -1.263506
# 2015-01-07   -1.849705     -0.983645     -0.905029      -1.263506
# ...                ...           ...           ...            ...
# 2023-12-25    1.755244      1.330780      1.313349       1.949319
# 2023-12-26    1.675956      1.330780      1.313349       1.949319
# 2023-12-27    1.699742      1.330780      1.313349       1.949319
# 2023-12-28    1.686528      1.330780      1.313349       1.949319
# 2023-12-29    1.660098      1.330780      1.313349       1.949319
#
#             volume_export
# date
# 2015-01-01      -1.399855
# 2015-01-02      -1.399855
# 2015-01-05      -1.399855
# 2015-01-06      -1.399855
# 2015-01-07      -1.399855
# ...                   ...
# 2023-12-25       1.665441
# 2023-12-26       1.665441
# 2023-12-27       1.665441
# 2023-12-28       1.665441
# 2023-12-29       1.665441
#
# [2292 rows x 5 columns]

# %%
df_scaled[['kurs_close', 'value_import', 'value_export', 'volume_import', 'volume_export']].hist(bins=30, figsize=(10, 8))
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 15)
figure, axes = plt.subplots(5)

for ax, col in zip(axes, df_scaled.columns):
    ax.plot(df_scaled[col])
    ax.set_title(col)
    ax.axes.xaxis.set_visible(False)

# %%
test_split=round(len(df_scaled)*0.20)
training=df_scaled[:1834]
testing=df_scaled[1834:]

# %%
def createXY(data,timestep):
    x = []
    y = []
    for i in range(timestep, len(data)):
            x.append(data.iloc[i-timestep:i].values)
            y.append(data.iloc[i].values)
    return np.array(x),np.array(y)
timestep = 30
x_train, y_train = createXY(training, timestep)
x_test, y_test = createXY(testing, timestep)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1804, 30, 5)
# (1804, 5)
# (428, 30, 5)
# (428, 5)

# %%
model1 = Sequential()
model1.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(x_train.shape[1], x_train.shape[2])))
model1.add(Dropout(0.2))
model1.add(Bidirectional(LSTM(64, return_sequences=True)))
model1.add(Dropout(0.2))
model1.add(Bidirectional(LSTM(32, return_sequences=True)))
model1.add(Dropout(0.2))
model1.add(Bidirectional(LSTM(16, return_sequences=False)))
model1.add(Dropout(0.2))
model1.add(Dense(y_train.shape[1]))
model1.summary()
# Out:
# c:\Users\LOQ\Documents\Coding\belajar-bilstm\bilstmvenv\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_4 (Bidirectional) │ (None, 30, 256)        │       137,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 30, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_6 (Bidirectional) │ (None, 30, 64)         │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ (None, 32)             │        10,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 353,317 (1.35 MB)
#  Trainable params: 353,317 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
history = model1.fit(x_train, y_train, epochs=480, batch_size=8, validation_data=(x_test, y_test))
# Out:
# Epoch 1/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - loss: 0.2572 - root_mean_squared_error: 0.4999 - val_loss: 0.7685 - val_root_mean_squared_error: 0.8767
# Epoch 2/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0872 - root_mean_squared_error: 0.2952 - val_loss: 0.6694 - val_root_mean_squared_error: 0.8182
# Epoch 3/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0691 - root_mean_squared_error: 0.2626 - val_loss: 0.6300 - val_root_mean_squared_error: 0.7937
# Epoch 4/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0587 - root_mean_squared_error: 0.2422 - val_loss: 0.5341 - val_root_mean_squared_error: 0.7308
# Epoch 5/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0504 - root_mean_squared_error: 0.2242 - val_loss: 0.5391 - val_root_mean_squared_error: 0.7342
# Epoch 6/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0468 - root_mean_squared_error: 0.2164 - val_loss: 0.5125 - val_root_mean_squared_error: 0.7159
# Epoch 7/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0447 - root_mean_squared_error: 0.2113 - val_loss: 0.4547 - val_root_mean_squared_error: 0.6743
# Epoch 8/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0384 - root_mean_squared_error: 0.1959 - val_loss: 0.5241 - val_root_mean_squared_error: 0.7240
# Epoch 9/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0432 - root_mean_squared_error: 0.2077 - val_loss: 0.5571 - val_root_mean_squared_error: 0.7464
# Epoch 10/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0361 - root_mean_squared_error: 0.1901 - val_loss: 0.6127 - val_root_mean_squared_error: 0.7827
# Epoch 11/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0365 - root_mean_squared_error: 0.1910 - val_loss: 0.5922 - val_root_mean_squared_error: 0.7696
# Epoch 12/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0343 - root_mean_squared_error: 0.1852 - val_loss: 0.7118 - val_root_mean_squared_error: 0.8437
# Epoch 13/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0363 - root_mean_squared_error: 0.1904 - val_loss: 0.6942 - val_root_mean_squared_error: 0.8332
# Epoch 14/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0325 - root_mean_squared_error: 0.1801 - val_loss: 0.6777 - val_root_mean_squared_error: 0.8232
# Epoch 15/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0341 - root_mean_squared_error: 0.1844 - val_loss: 0.6917 - val_root_mean_squared_error: 0.8317
# Epoch 16/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0308 - root_mean_squared_error: 0.1755 - val_loss: 0.7065 - val_root_mean_squared_error: 0.8405
# Epoch 17/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0297 - root_mean_squared_error: 0.1721 - val_loss: 0.6972 - val_root_mean_squared_error: 0.8350
# Epoch 18/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0313 - root_mean_squared_error: 0.1768 - val_loss: 0.7563 - val_root_mean_squared_error: 0.8696
# Epoch 19/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0333 - root_mean_squared_error: 0.1819 - val_loss: 0.7413 - val_root_mean_squared_error: 0.8610
# Epoch 20/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0297 - root_mean_squared_error: 0.1722 - val_loss: 0.7789 - val_root_mean_squared_error: 0.8825
# Epoch 21/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0324 - root_mean_squared_error: 0.1789 - val_loss: 0.6723 - val_root_mean_squared_error: 0.8199
# Epoch 22/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673 - val_loss: 0.7899 - val_root_mean_squared_error: 0.8887
# Epoch 23/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0277 - root_mean_squared_error: 0.1664 - val_loss: 0.7238 - val_root_mean_squared_error: 0.8508
# Epoch 24/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688 - val_loss: 0.7359 - val_root_mean_squared_error: 0.8578
# Epoch 25/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0263 - root_mean_squared_error: 0.1619 - val_loss: 0.7546 - val_root_mean_squared_error: 0.8687
# Epoch 26/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - val_loss: 0.6830 - val_root_mean_squared_error: 0.8264
# Epoch 27/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0309 - root_mean_squared_error: 0.1748 - val_loss: 0.7688 - val_root_mean_squared_error: 0.8768
# Epoch 28/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.7770 - val_root_mean_squared_error: 0.8815
# Epoch 29/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.8175 - val_root_mean_squared_error: 0.9041
# Epoch 30/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0248 - root_mean_squared_error: 0.1573 - val_loss: 0.7713 - val_root_mean_squared_error: 0.8782
# Epoch 31/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0250 - root_mean_squared_error: 0.1580 - val_loss: 0.7365 - val_root_mean_squared_error: 0.8582
# Epoch 32/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0254 - root_mean_squared_error: 0.1591 - val_loss: 0.8077 - val_root_mean_squared_error: 0.8987
# Epoch 33/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.7537 - val_root_mean_squared_error: 0.8682
# Epoch 34/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0271 - root_mean_squared_error: 0.1645 - val_loss: 0.7714 - val_root_mean_squared_error: 0.8783
# Epoch 35/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - val_loss: 0.7441 - val_root_mean_squared_error: 0.8626
# Epoch 36/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.7678 - val_root_mean_squared_error: 0.8762
# Epoch 37/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0237 - root_mean_squared_error: 0.1539 - val_loss: 0.7141 - val_root_mean_squared_error: 0.8450
# Epoch 38/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477 - val_loss: 0.7697 - val_root_mean_squared_error: 0.8773
# Epoch 39/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0231 - root_mean_squared_error: 0.1521 - val_loss: 0.7546 - val_root_mean_squared_error: 0.8687
# Epoch 40/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0206 - root_mean_squared_error: 0.1432 - val_loss: 0.7228 - val_root_mean_squared_error: 0.8502
# Epoch 41/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0230 - root_mean_squared_error: 0.1514 - val_loss: 0.7268 - val_root_mean_squared_error: 0.8525
# Epoch 42/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.6433 - val_root_mean_squared_error: 0.8020
# Epoch 43/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.6338 - val_root_mean_squared_error: 0.7961
# Epoch 44/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0229 - root_mean_squared_error: 0.1514 - val_loss: 0.6777 - val_root_mean_squared_error: 0.8232
# Epoch 45/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.7140 - val_root_mean_squared_error: 0.8450
# Epoch 46/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.7719 - val_root_mean_squared_error: 0.8786
# Epoch 47/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.7617 - val_root_mean_squared_error: 0.8727
# Epoch 48/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448 - val_loss: 0.7467 - val_root_mean_squared_error: 0.8641
# Epoch 49/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.7686 - val_root_mean_squared_error: 0.8767
# Epoch 50/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.6908 - val_root_mean_squared_error: 0.8311
# Epoch 51/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0230 - root_mean_squared_error: 0.1513 - val_loss: 0.6823 - val_root_mean_squared_error: 0.8260
# Epoch 52/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.7309 - val_root_mean_squared_error: 0.8549
# Epoch 53/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - val_loss: 0.7377 - val_root_mean_squared_error: 0.8589
# Epoch 54/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.7492 - val_root_mean_squared_error: 0.8656
# Epoch 55/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482 - val_loss: 0.7427 - val_root_mean_squared_error: 0.8618
# Epoch 56/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0186 - root_mean_squared_error: 0.1360 - val_loss: 0.7854 - val_root_mean_squared_error: 0.8862
# Epoch 57/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0220 - root_mean_squared_error: 0.1480 - val_loss: 0.7289 - val_root_mean_squared_error: 0.8537
# Epoch 58/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0207 - root_mean_squared_error: 0.1436 - val_loss: 0.7596 - val_root_mean_squared_error: 0.8716
# Epoch 59/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.7283 - val_root_mean_squared_error: 0.8534
# Epoch 60/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.6736 - val_root_mean_squared_error: 0.8207
# Epoch 61/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.7130 - val_root_mean_squared_error: 0.8444
# Epoch 62/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - val_loss: 0.6935 - val_root_mean_squared_error: 0.8328
# Epoch 63/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0204 - root_mean_squared_error: 0.1428 - val_loss: 0.6485 - val_root_mean_squared_error: 0.8053
# Epoch 64/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - val_loss: 0.6869 - val_root_mean_squared_error: 0.8288
# Epoch 65/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.7149 - val_root_mean_squared_error: 0.8455
# Epoch 66/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.6892 - val_root_mean_squared_error: 0.8302
# Epoch 67/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0179 - root_mean_squared_error: 0.1337 - val_loss: 0.7188 - val_root_mean_squared_error: 0.8478
# Epoch 68/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0212 - root_mean_squared_error: 0.1453 - val_loss: 0.7221 - val_root_mean_squared_error: 0.8498
# Epoch 69/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392 - val_loss: 0.6828 - val_root_mean_squared_error: 0.8263
# Epoch 70/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0205 - root_mean_squared_error: 0.1430 - val_loss: 0.7007 - val_root_mean_squared_error: 0.8371
# Epoch 71/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0181 - root_mean_squared_error: 0.1342 - val_loss: 0.6927 - val_root_mean_squared_error: 0.8323
# Epoch 72/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6884 - val_root_mean_squared_error: 0.8297
# Epoch 73/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0209 - root_mean_squared_error: 0.1444 - val_loss: 0.6460 - val_root_mean_squared_error: 0.8037
# Epoch 74/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0193 - root_mean_squared_error: 0.1387 - val_loss: 0.6418 - val_root_mean_squared_error: 0.8011
# Epoch 75/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.6815 - val_root_mean_squared_error: 0.8255
# Epoch 76/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0189 - root_mean_squared_error: 0.1372 - val_loss: 0.6668 - val_root_mean_squared_error: 0.8166
# Epoch 77/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0194 - root_mean_squared_error: 0.1390 - val_loss: 0.7426 - val_root_mean_squared_error: 0.8617
# Epoch 78/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0194 - root_mean_squared_error: 0.1391 - val_loss: 0.6607 - val_root_mean_squared_error: 0.8128
# Epoch 79/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.7460 - val_root_mean_squared_error: 0.8637
# Epoch 80/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0212 - root_mean_squared_error: 0.1453 - val_loss: 0.7221 - val_root_mean_squared_error: 0.8498
# Epoch 81/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365 - val_loss: 0.6929 - val_root_mean_squared_error: 0.8324
# Epoch 82/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381 - val_loss: 0.7162 - val_root_mean_squared_error: 0.8463
# Epoch 83/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355 - val_loss: 0.6834 - val_root_mean_squared_error: 0.8267
# Epoch 84/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - val_loss: 0.6730 - val_root_mean_squared_error: 0.8203
# Epoch 85/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0198 - root_mean_squared_error: 0.1405 - val_loss: 0.6921 - val_root_mean_squared_error: 0.8319
# Epoch 86/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0198 - root_mean_squared_error: 0.1403 - val_loss: 0.6775 - val_root_mean_squared_error: 0.8231
# Epoch 87/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0200 - root_mean_squared_error: 0.1411 - val_loss: 0.6855 - val_root_mean_squared_error: 0.8280
# Epoch 88/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411 - val_loss: 0.7204 - val_root_mean_squared_error: 0.8488
# Epoch 89/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - val_loss: 0.6981 - val_root_mean_squared_error: 0.8355
# Epoch 90/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0204 - root_mean_squared_error: 0.1425 - val_loss: 0.7055 - val_root_mean_squared_error: 0.8400
# Epoch 91/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0192 - root_mean_squared_error: 0.1385 - val_loss: 0.6569 - val_root_mean_squared_error: 0.8105
# Epoch 92/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.6559 - val_root_mean_squared_error: 0.8099
# Epoch 93/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - val_loss: 0.6614 - val_root_mean_squared_error: 0.8132
# Epoch 94/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0192 - root_mean_squared_error: 0.1381 - val_loss: 0.6796 - val_root_mean_squared_error: 0.8244
# Epoch 95/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0187 - root_mean_squared_error: 0.1365 - val_loss: 0.6549 - val_root_mean_squared_error: 0.8092
# Epoch 96/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - val_loss: 0.6622 - val_root_mean_squared_error: 0.8138
# Epoch 97/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.6697 - val_root_mean_squared_error: 0.8184
# Epoch 98/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0191 - root_mean_squared_error: 0.1379 - val_loss: 0.6593 - val_root_mean_squared_error: 0.8120
# Epoch 99/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.0188 - root_mean_squared_error: 0.1369 - val_loss: 0.6802 - val_root_mean_squared_error: 0.8248
# Epoch 100/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - val_loss: 0.6604 - val_root_mean_squared_error: 0.8127
# Epoch 101/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0177 - root_mean_squared_error: 0.1328 - val_loss: 0.6845 - val_root_mean_squared_error: 0.8273
# Epoch 102/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0197 - root_mean_squared_error: 0.1401 - val_loss: 0.6876 - val_root_mean_squared_error: 0.8292
# Epoch 103/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0176 - root_mean_squared_error: 0.1324 - val_loss: 0.6987 - val_root_mean_squared_error: 0.8359
# Epoch 104/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.6957 - val_root_mean_squared_error: 0.8341
# Epoch 105/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.6851 - val_root_mean_squared_error: 0.8277
# Epoch 106/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326 - val_loss: 0.6903 - val_root_mean_squared_error: 0.8309
# Epoch 107/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.6691 - val_root_mean_squared_error: 0.8180
# Epoch 108/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.6740 - val_root_mean_squared_error: 0.8210
# Epoch 109/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - val_loss: 0.7040 - val_root_mean_squared_error: 0.8390
# Epoch 110/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.6672 - val_root_mean_squared_error: 0.8168
# Epoch 111/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - val_loss: 0.7044 - val_root_mean_squared_error: 0.8393
# Epoch 112/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0186 - root_mean_squared_error: 0.1363 - val_loss: 0.6761 - val_root_mean_squared_error: 0.8222
# Epoch 113/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.6654 - val_root_mean_squared_error: 0.8157
# Epoch 114/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.6500 - val_root_mean_squared_error: 0.8062
# Epoch 115/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.6253 - val_root_mean_squared_error: 0.7908
# Epoch 116/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.7031 - val_root_mean_squared_error: 0.8385
# Epoch 117/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6698 - val_root_mean_squared_error: 0.8184
# Epoch 118/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0181 - root_mean_squared_error: 0.1342 - val_loss: 0.6846 - val_root_mean_squared_error: 0.8274
# Epoch 119/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.6701 - val_root_mean_squared_error: 0.8186
# Epoch 120/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0212 - root_mean_squared_error: 0.1450 - val_loss: 0.7173 - val_root_mean_squared_error: 0.8469
# Epoch 121/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.7024 - val_root_mean_squared_error: 0.8381
# Epoch 122/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - val_loss: 0.6789 - val_root_mean_squared_error: 0.8240
# Epoch 123/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0190 - root_mean_squared_error: 0.1376 - val_loss: 0.6834 - val_root_mean_squared_error: 0.8267
# Epoch 124/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0178 - root_mean_squared_error: 0.1331 - val_loss: 0.6405 - val_root_mean_squared_error: 0.8003
# Epoch 125/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0189 - root_mean_squared_error: 0.1371 - val_loss: 0.6757 - val_root_mean_squared_error: 0.8220
# Epoch 126/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0193 - root_mean_squared_error: 0.1385 - val_loss: 0.6583 - val_root_mean_squared_error: 0.8114
# Epoch 127/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.7007 - val_root_mean_squared_error: 0.8371
# Epoch 128/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1317 - val_loss: 0.6624 - val_root_mean_squared_error: 0.8139
# Epoch 129/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.7233 - val_root_mean_squared_error: 0.8505
# Epoch 130/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.6936 - val_root_mean_squared_error: 0.8328
# Epoch 131/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0177 - root_mean_squared_error: 0.1328 - val_loss: 0.6704 - val_root_mean_squared_error: 0.8188
# Epoch 132/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0180 - root_mean_squared_error: 0.1339 - val_loss: 0.6822 - val_root_mean_squared_error: 0.8260
# Epoch 133/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - val_loss: 0.6902 - val_root_mean_squared_error: 0.8308
# Epoch 134/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373 - val_loss: 0.6886 - val_root_mean_squared_error: 0.8298
# Epoch 135/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1317 - val_loss: 0.7069 - val_root_mean_squared_error: 0.8408
# Epoch 136/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0194 - root_mean_squared_error: 0.1380 - val_loss: 0.7006 - val_root_mean_squared_error: 0.8370
# Epoch 137/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0177 - root_mean_squared_error: 0.1327 - val_loss: 0.6940 - val_root_mean_squared_error: 0.8331
# Epoch 138/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0172 - root_mean_squared_error: 0.1310 - val_loss: 0.6718 - val_root_mean_squared_error: 0.8196
# Epoch 139/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.6373 - val_root_mean_squared_error: 0.7983
# Epoch 140/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - val_loss: 0.7050 - val_root_mean_squared_error: 0.8396
# Epoch 141/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0177 - root_mean_squared_error: 0.1328 - val_loss: 0.6799 - val_root_mean_squared_error: 0.8245
# Epoch 142/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0159 - root_mean_squared_error: 0.1261 - val_loss: 0.6401 - val_root_mean_squared_error: 0.8001
# Epoch 143/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.6382 - val_root_mean_squared_error: 0.7989
# Epoch 144/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.6986 - val_root_mean_squared_error: 0.8358
# Epoch 145/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - val_loss: 0.6666 - val_root_mean_squared_error: 0.8164
# Epoch 146/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.6909 - val_root_mean_squared_error: 0.8312
# Epoch 147/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0181 - root_mean_squared_error: 0.1341 - val_loss: 0.6703 - val_root_mean_squared_error: 0.8187
# Epoch 148/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0185 - root_mean_squared_error: 0.1357 - val_loss: 0.6661 - val_root_mean_squared_error: 0.8161
# Epoch 149/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.7100 - val_root_mean_squared_error: 0.8426
# Epoch 150/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.7119 - val_root_mean_squared_error: 0.8438
# Epoch 151/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.6568 - val_root_mean_squared_error: 0.8104
# Epoch 152/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - val_loss: 0.6729 - val_root_mean_squared_error: 0.8203
# Epoch 153/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0162 - root_mean_squared_error: 0.1270 - val_loss: 0.6785 - val_root_mean_squared_error: 0.8237
# Epoch 154/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1317 - val_loss: 0.6987 - val_root_mean_squared_error: 0.8359
# Epoch 155/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0195 - root_mean_squared_error: 0.1393 - val_loss: 0.7305 - val_root_mean_squared_error: 0.8547
# Epoch 156/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - val_loss: 0.6817 - val_root_mean_squared_error: 0.8257
# Epoch 157/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0182 - root_mean_squared_error: 0.1347 - val_loss: 0.6714 - val_root_mean_squared_error: 0.8194
# Epoch 158/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0183 - root_mean_squared_error: 0.1352 - val_loss: 0.6774 - val_root_mean_squared_error: 0.8230
# Epoch 159/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.6652 - val_root_mean_squared_error: 0.8156
# Epoch 160/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0184 - root_mean_squared_error: 0.1356 - val_loss: 0.6984 - val_root_mean_squared_error: 0.8357
# Epoch 161/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.6821 - val_root_mean_squared_error: 0.8259
# Epoch 162/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.6519 - val_root_mean_squared_error: 0.8074
# Epoch 163/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - val_loss: 0.6937 - val_root_mean_squared_error: 0.8329
# Epoch 164/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0164 - root_mean_squared_error: 0.1278 - val_loss: 0.6781 - val_root_mean_squared_error: 0.8235
# Epoch 165/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0182 - root_mean_squared_error: 0.1347 - val_loss: 0.6792 - val_root_mean_squared_error: 0.8241
# Epoch 166/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0171 - root_mean_squared_error: 0.1305 - val_loss: 0.6854 - val_root_mean_squared_error: 0.8279
# Epoch 167/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.6797 - val_root_mean_squared_error: 0.8244
# Epoch 168/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373 - val_loss: 0.6701 - val_root_mean_squared_error: 0.8186
# Epoch 169/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1285 - val_loss: 0.6350 - val_root_mean_squared_error: 0.7969
# Epoch 170/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1313 - val_loss: 0.7150 - val_root_mean_squared_error: 0.8456
# Epoch 171/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1285 - val_loss: 0.6454 - val_root_mean_squared_error: 0.8034
# Epoch 172/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.6643 - val_root_mean_squared_error: 0.8150
# Epoch 173/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.6551 - val_root_mean_squared_error: 0.8094
# Epoch 174/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0160 - root_mean_squared_error: 0.1262 - val_loss: 0.6675 - val_root_mean_squared_error: 0.8170
# Epoch 175/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1349 - val_loss: 0.6711 - val_root_mean_squared_error: 0.8192
# Epoch 176/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1257 - val_loss: 0.7063 - val_root_mean_squared_error: 0.8404
# Epoch 177/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.6819 - val_root_mean_squared_error: 0.8258
# Epoch 178/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0186 - root_mean_squared_error: 0.1356 - val_loss: 0.7067 - val_root_mean_squared_error: 0.8406
# Epoch 179/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0184 - root_mean_squared_error: 0.1358 - val_loss: 0.6631 - val_root_mean_squared_error: 0.8143
# Epoch 180/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223 - val_loss: 0.6424 - val_root_mean_squared_error: 0.8015
# Epoch 181/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.6789 - val_root_mean_squared_error: 0.8239
# Epoch 182/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.6832 - val_root_mean_squared_error: 0.8266
# Epoch 183/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - val_loss: 0.6734 - val_root_mean_squared_error: 0.8206
# Epoch 184/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0167 - root_mean_squared_error: 0.1290 - val_loss: 0.7222 - val_root_mean_squared_error: 0.8498
# Epoch 185/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.6931 - val_root_mean_squared_error: 0.8325
# Epoch 186/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6742 - val_root_mean_squared_error: 0.8211
# Epoch 187/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6694 - val_root_mean_squared_error: 0.8182
# Epoch 188/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0186 - root_mean_squared_error: 0.1359 - val_loss: 0.6648 - val_root_mean_squared_error: 0.8153
# Epoch 189/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.6933 - val_root_mean_squared_error: 0.8326
# Epoch 190/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0177 - root_mean_squared_error: 0.1325 - val_loss: 0.6632 - val_root_mean_squared_error: 0.8144
# Epoch 191/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1274 - val_loss: 0.7002 - val_root_mean_squared_error: 0.8368
# Epoch 192/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.6484 - val_root_mean_squared_error: 0.8052
# Epoch 193/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1339 - val_loss: 0.6824 - val_root_mean_squared_error: 0.8261
# Epoch 194/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0201 - root_mean_squared_error: 0.1406 - val_loss: 0.6779 - val_root_mean_squared_error: 0.8233
# Epoch 195/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0177 - root_mean_squared_error: 0.1328 - val_loss: 0.6991 - val_root_mean_squared_error: 0.8361
# Epoch 196/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0190 - root_mean_squared_error: 0.1375 - val_loss: 0.6950 - val_root_mean_squared_error: 0.8337
# Epoch 197/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1287 - val_loss: 0.6875 - val_root_mean_squared_error: 0.8292
# Epoch 198/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6515 - val_root_mean_squared_error: 0.8072
# Epoch 199/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0224 - root_mean_squared_error: 0.1494 - val_loss: 0.7239 - val_root_mean_squared_error: 0.8508
# Epoch 200/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.7249 - val_root_mean_squared_error: 0.8514
# Epoch 201/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.6562 - val_root_mean_squared_error: 0.8101
# Epoch 202/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.6801 - val_root_mean_squared_error: 0.8247
# Epoch 203/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.6772 - val_root_mean_squared_error: 0.8229
# Epoch 204/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.6897 - val_root_mean_squared_error: 0.8305
# Epoch 205/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - val_loss: 0.6881 - val_root_mean_squared_error: 0.8295
# Epoch 206/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1285 - val_loss: 0.7050 - val_root_mean_squared_error: 0.8396
# Epoch 207/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1286 - val_loss: 0.6861 - val_root_mean_squared_error: 0.8283
# Epoch 208/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0184 - root_mean_squared_error: 0.1353 - val_loss: 0.6696 - val_root_mean_squared_error: 0.8183
# Epoch 209/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.8910 - val_root_mean_squared_error: 0.9439
# Epoch 210/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0244 - root_mean_squared_error: 0.1561 - val_loss: 0.8033 - val_root_mean_squared_error: 0.8962
# Epoch 211/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345 - val_loss: 0.7446 - val_root_mean_squared_error: 0.8629
# Epoch 212/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.7464 - val_root_mean_squared_error: 0.8639
# Epoch 213/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336 - val_loss: 0.7217 - val_root_mean_squared_error: 0.8495
# Epoch 214/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1313 - val_loss: 0.6648 - val_root_mean_squared_error: 0.8153
# Epoch 215/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346 - val_loss: 0.6871 - val_root_mean_squared_error: 0.8289
# Epoch 216/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0198 - root_mean_squared_error: 0.1396 - val_loss: 0.7297 - val_root_mean_squared_error: 0.8542
# Epoch 217/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0182 - root_mean_squared_error: 0.1346 - val_loss: 0.7059 - val_root_mean_squared_error: 0.8402
# Epoch 218/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.7143 - val_root_mean_squared_error: 0.8452
# Epoch 219/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.7030 - val_root_mean_squared_error: 0.8384
# Epoch 220/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276 - val_loss: 0.6793 - val_root_mean_squared_error: 0.8242
# Epoch 221/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - val_loss: 0.6640 - val_root_mean_squared_error: 0.8148
# Epoch 222/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - val_loss: 0.7058 - val_root_mean_squared_error: 0.8401
# Epoch 223/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.7045 - val_root_mean_squared_error: 0.8393
# Epoch 224/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.7106 - val_root_mean_squared_error: 0.8430
# Epoch 225/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.6555 - val_root_mean_squared_error: 0.8096
# Epoch 226/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0161 - root_mean_squared_error: 0.1267 - val_loss: 0.6548 - val_root_mean_squared_error: 0.8092
# Epoch 227/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.6932 - val_root_mean_squared_error: 0.8326
# Epoch 228/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.6783 - val_root_mean_squared_error: 0.8236
# Epoch 229/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0172 - root_mean_squared_error: 0.1311 - val_loss: 0.6750 - val_root_mean_squared_error: 0.8216
# Epoch 230/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0179 - root_mean_squared_error: 0.1339 - val_loss: 0.6864 - val_root_mean_squared_error: 0.8285
# Epoch 231/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.6697 - val_root_mean_squared_error: 0.8184
# Epoch 232/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.6654 - val_root_mean_squared_error: 0.8157
# Epoch 233/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.6719 - val_root_mean_squared_error: 0.8197
# Epoch 234/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1316 - val_loss: 0.6728 - val_root_mean_squared_error: 0.8202
# Epoch 235/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0181 - root_mean_squared_error: 0.1342 - val_loss: 0.6877 - val_root_mean_squared_error: 0.8293
# Epoch 236/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - val_loss: 0.6504 - val_root_mean_squared_error: 0.8064
# Epoch 237/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.6611 - val_root_mean_squared_error: 0.8131
# Epoch 238/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.7193 - val_root_mean_squared_error: 0.8481
# Epoch 239/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.6903 - val_root_mean_squared_error: 0.8308
# Epoch 240/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1259 - val_loss: 0.6989 - val_root_mean_squared_error: 0.8360
# Epoch 241/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1256 - val_loss: 0.6656 - val_root_mean_squared_error: 0.8158
# Epoch 242/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0191 - root_mean_squared_error: 0.1376 - val_loss: 0.6633 - val_root_mean_squared_error: 0.8144
# Epoch 243/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.6548 - val_root_mean_squared_error: 0.8092
# Epoch 244/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0175 - root_mean_squared_error: 0.1321 - val_loss: 0.6670 - val_root_mean_squared_error: 0.8167
# Epoch 245/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.6710 - val_root_mean_squared_error: 0.8192
# Epoch 246/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1346 - val_loss: 0.6622 - val_root_mean_squared_error: 0.8137
# Epoch 247/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0176 - root_mean_squared_error: 0.1324 - val_loss: 0.6867 - val_root_mean_squared_error: 0.8287
# Epoch 248/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.6952 - val_root_mean_squared_error: 0.8338
# Epoch 249/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0164 - root_mean_squared_error: 0.1278 - val_loss: 0.7135 - val_root_mean_squared_error: 0.8447
# Epoch 250/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1315 - val_loss: 0.6886 - val_root_mean_squared_error: 0.8298
# Epoch 251/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0168 - root_mean_squared_error: 0.1294 - val_loss: 0.6738 - val_root_mean_squared_error: 0.8209
# Epoch 252/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.7032 - val_root_mean_squared_error: 0.8386
# Epoch 253/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0176 - root_mean_squared_error: 0.1324 - val_loss: 0.6460 - val_root_mean_squared_error: 0.8037
# Epoch 254/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.6774 - val_root_mean_squared_error: 0.8230
# Epoch 255/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.6966 - val_root_mean_squared_error: 0.8346
# Epoch 256/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195 - val_loss: 0.6677 - val_root_mean_squared_error: 0.8171
# Epoch 257/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.6730 - val_root_mean_squared_error: 0.8204
# Epoch 258/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 0.6712 - val_root_mean_squared_error: 0.8193
# Epoch 259/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - val_loss: 0.6882 - val_root_mean_squared_error: 0.8296
# Epoch 260/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.6958 - val_root_mean_squared_error: 0.8341
# Epoch 261/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0187 - root_mean_squared_error: 0.1364 - val_loss: 0.6806 - val_root_mean_squared_error: 0.8250
# Epoch 262/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327 - val_loss: 0.7115 - val_root_mean_squared_error: 0.8435
# Epoch 263/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.6815 - val_root_mean_squared_error: 0.8255
# Epoch 264/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.6876 - val_root_mean_squared_error: 0.8292
# Epoch 265/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0156 - root_mean_squared_error: 0.1246 - val_loss: 0.7009 - val_root_mean_squared_error: 0.8372
# Epoch 266/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - val_loss: 0.7362 - val_root_mean_squared_error: 0.8580
# Epoch 267/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0164 - root_mean_squared_error: 0.1279 - val_loss: 0.7181 - val_root_mean_squared_error: 0.8474
# Epoch 268/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1282 - val_loss: 0.6915 - val_root_mean_squared_error: 0.8316
# Epoch 269/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.7481 - val_root_mean_squared_error: 0.8649
# Epoch 270/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.7237 - val_root_mean_squared_error: 0.8507
# Epoch 271/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318 - val_loss: 0.6921 - val_root_mean_squared_error: 0.8319
# Epoch 272/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0152 - root_mean_squared_error: 0.1234 - val_loss: 0.7249 - val_root_mean_squared_error: 0.8514
# Epoch 273/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0184 - root_mean_squared_error: 0.1354 - val_loss: 0.7855 - val_root_mean_squared_error: 0.8863
# Epoch 274/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.7480 - val_root_mean_squared_error: 0.8648
# Epoch 275/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1253 - val_loss: 0.6478 - val_root_mean_squared_error: 0.8048
# Epoch 276/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.7256 - val_root_mean_squared_error: 0.8518
# Epoch 277/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.6898 - val_root_mean_squared_error: 0.8305
# Epoch 278/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235 - val_loss: 0.7191 - val_root_mean_squared_error: 0.8480
# Epoch 279/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0158 - root_mean_squared_error: 0.1254 - val_loss: 0.7144 - val_root_mean_squared_error: 0.8452
# Epoch 280/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0169 - root_mean_squared_error: 0.1300 - val_loss: 0.6738 - val_root_mean_squared_error: 0.8208
# Epoch 281/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0149 - root_mean_squared_error: 0.1219 - val_loss: 0.7703 - val_root_mean_squared_error: 0.8777
# Epoch 282/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1268 - val_loss: 0.7911 - val_root_mean_squared_error: 0.8894
# Epoch 283/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274 - val_loss: 0.6887 - val_root_mean_squared_error: 0.8299
# Epoch 284/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1338 - val_loss: 0.6637 - val_root_mean_squared_error: 0.8147
# Epoch 285/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0154 - root_mean_squared_error: 0.1238 - val_loss: 0.6842 - val_root_mean_squared_error: 0.8272
# Epoch 286/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1270 - val_loss: 0.7166 - val_root_mean_squared_error: 0.8465
# Epoch 287/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0149 - root_mean_squared_error: 0.1217 - val_loss: 0.7597 - val_root_mean_squared_error: 0.8716
# Epoch 288/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0188 - root_mean_squared_error: 0.1368 - val_loss: 0.7211 - val_root_mean_squared_error: 0.8492
# Epoch 289/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 0.7281 - val_root_mean_squared_error: 0.8533
# Epoch 290/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.7312 - val_root_mean_squared_error: 0.8551
# Epoch 291/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0192 - root_mean_squared_error: 0.1379 - val_loss: 0.6707 - val_root_mean_squared_error: 0.8190
# Epoch 292/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.7207 - val_root_mean_squared_error: 0.8490
# Epoch 293/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - val_loss: 0.6837 - val_root_mean_squared_error: 0.8269
# Epoch 294/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0168 - root_mean_squared_error: 0.1293 - val_loss: 0.7295 - val_root_mean_squared_error: 0.8541
# Epoch 295/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.7544 - val_root_mean_squared_error: 0.8685
# Epoch 296/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.7099 - val_root_mean_squared_error: 0.8426
# Epoch 297/480
# ...
# Epoch 383/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0172 - root_mean_squared_error: 0.1305 - val_loss: 0.8762 - val_root_mean_squared_error: 0.9361
# Epoch 384/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.9968 - val_root_mean_squared_error: 0.9984
# Epoch 385/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0143 - root_mean_squared_error: 0.1196 - val_loss: 0.8652 - val_root_mean_squared_error: 0.9302
# Epoch 386/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0167 - root_mean_squared_error: 0.1291 - val_loss: 0.8885 - val_root_mean_squared_error: 0.9426
# Epoch 387/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.8893 - val_root_mean_squared_error: 0.9430
# Epoch 388/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.9061 - val_root_mean_squared_error: 0.9519
# Epoch 389/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 1.0456 - val_root_mean_squared_error: 1.0225
# Epoch 390/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0150 - root_mean_squared_error: 0.1222 - val_loss: 1.0150 - val_root_mean_squared_error: 1.0075
# Epoch 391/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 1.0151 - val_root_mean_squared_error: 1.0075
# Epoch 392/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0153 - root_mean_squared_error: 0.1236 - val_loss: 0.9980 - val_root_mean_squared_error: 0.9990
# Epoch 393/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0194 - root_mean_squared_error: 0.1383 - val_loss: 1.0064 - val_root_mean_squared_error: 1.0032
# Epoch 394/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 1.0518 - val_root_mean_squared_error: 1.0256
# Epoch 395/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0167 - root_mean_squared_error: 0.1285 - val_loss: 0.9271 - val_root_mean_squared_error: 0.9629
# Epoch 396/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0179 - root_mean_squared_error: 0.1336 - val_loss: 0.9911 - val_root_mean_squared_error: 0.9955
# Epoch 397/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 1.0788 - val_root_mean_squared_error: 1.0387
# Epoch 398/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0165 - root_mean_squared_error: 0.1284 - val_loss: 1.0244 - val_root_mean_squared_error: 1.0121
# Epoch 399/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.9772 - val_root_mean_squared_error: 0.9885
# Epoch 400/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266 - val_loss: 1.0556 - val_root_mean_squared_error: 1.0274
# Epoch 401/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1250 - val_loss: 0.9331 - val_root_mean_squared_error: 0.9660
# Epoch 402/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - val_loss: 1.0147 - val_root_mean_squared_error: 1.0073
# Epoch 403/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - val_loss: 0.9813 - val_root_mean_squared_error: 0.9906
# Epoch 404/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.9225 - val_root_mean_squared_error: 0.9605
# Epoch 405/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.9674 - val_root_mean_squared_error: 0.9836
# Epoch 406/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 1.0031 - val_root_mean_squared_error: 1.0015
# Epoch 407/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0156 - root_mean_squared_error: 0.1246 - val_loss: 0.8565 - val_root_mean_squared_error: 0.9255
# Epoch 408/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0164 - root_mean_squared_error: 0.1278 - val_loss: 0.7831 - val_root_mean_squared_error: 0.8849
# Epoch 409/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0173 - root_mean_squared_error: 0.1312 - val_loss: 0.7446 - val_root_mean_squared_error: 0.8629
# Epoch 410/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212 - val_loss: 0.8200 - val_root_mean_squared_error: 0.9056
# Epoch 411/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237 - val_loss: 0.9692 - val_root_mean_squared_error: 0.9845
# Epoch 412/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 1.0574 - val_root_mean_squared_error: 1.0283
# Epoch 413/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 1.0080 - val_root_mean_squared_error: 1.0040
# Epoch 414/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.9182 - val_root_mean_squared_error: 0.9582
# Epoch 415/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.8666 - val_root_mean_squared_error: 0.9309
# Epoch 416/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1339 - val_loss: 0.9840 - val_root_mean_squared_error: 0.9919
# Epoch 417/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.8837 - val_root_mean_squared_error: 0.9400
# Epoch 418/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289 - val_loss: 0.8555 - val_root_mean_squared_error: 0.9249
# Epoch 419/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.8785 - val_root_mean_squared_error: 0.9373
# Epoch 420/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0173 - root_mean_squared_error: 0.1312 - val_loss: 0.8233 - val_root_mean_squared_error: 0.9073
# Epoch 421/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.7763 - val_root_mean_squared_error: 0.8811
# Epoch 422/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215 - val_loss: 0.8167 - val_root_mean_squared_error: 0.9037
# Epoch 423/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1269 - val_loss: 0.8960 - val_root_mean_squared_error: 0.9466
# Epoch 424/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - val_loss: 0.8735 - val_root_mean_squared_error: 0.9346
# Epoch 425/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.9077 - val_root_mean_squared_error: 0.9527
# Epoch 426/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.7974 - val_root_mean_squared_error: 0.8930
# Epoch 427/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.8508 - val_root_mean_squared_error: 0.9224
# Epoch 428/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255 - val_loss: 0.7632 - val_root_mean_squared_error: 0.8736
# Epoch 429/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - val_loss: 0.7493 - val_root_mean_squared_error: 0.8656
# Epoch 430/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - val_loss: 0.9320 - val_root_mean_squared_error: 0.9654
# Epoch 431/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0166 - root_mean_squared_error: 0.1286 - val_loss: 0.8601 - val_root_mean_squared_error: 0.9274
# Epoch 432/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0170 - root_mean_squared_error: 0.1302 - val_loss: 0.9396 - val_root_mean_squared_error: 0.9693
# Epoch 433/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.9230 - val_root_mean_squared_error: 0.9607
# Epoch 434/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - val_loss: 0.8491 - val_root_mean_squared_error: 0.9214
# Epoch 435/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231 - val_loss: 0.9464 - val_root_mean_squared_error: 0.9728
# Epoch 436/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0149 - root_mean_squared_error: 0.1220 - val_loss: 0.8416 - val_root_mean_squared_error: 0.9174
# Epoch 437/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - val_loss: 0.7795 - val_root_mean_squared_error: 0.8829
# Epoch 438/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 1.0265 - val_root_mean_squared_error: 1.0132
# Epoch 439/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.9053 - val_root_mean_squared_error: 0.9515
# Epoch 440/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.9539 - val_root_mean_squared_error: 0.9767
# Epoch 441/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0174 - root_mean_squared_error: 0.1316 - val_loss: 0.8989 - val_root_mean_squared_error: 0.9481
# Epoch 442/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.7806 - val_root_mean_squared_error: 0.8835
# Epoch 443/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.8268 - val_root_mean_squared_error: 0.9093
# Epoch 444/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0138 - root_mean_squared_error: 0.1172 - val_loss: 0.8329 - val_root_mean_squared_error: 0.9127
# Epoch 445/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.9930 - val_root_mean_squared_error: 0.9965
# Epoch 446/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0168 - root_mean_squared_error: 0.1295 - val_loss: 0.9019 - val_root_mean_squared_error: 0.9497
# Epoch 447/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0162 - root_mean_squared_error: 0.1270 - val_loss: 0.7760 - val_root_mean_squared_error: 0.8809
# Epoch 448/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0155 - root_mean_squared_error: 0.1244 - val_loss: 0.8766 - val_root_mean_squared_error: 0.9363
# Epoch 449/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0163 - root_mean_squared_error: 0.1273 - val_loss: 0.8323 - val_root_mean_squared_error: 0.9123
# Epoch 450/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.8007 - val_root_mean_squared_error: 0.8948
# Epoch 451/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208 - val_loss: 0.8561 - val_root_mean_squared_error: 0.9252
# Epoch 452/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0162 - root_mean_squared_error: 0.1271 - val_loss: 0.8953 - val_root_mean_squared_error: 0.9462
# Epoch 453/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243 - val_loss: 0.8591 - val_root_mean_squared_error: 0.9269
# Epoch 454/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226 - val_loss: 0.8623 - val_root_mean_squared_error: 0.9286
# Epoch 455/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0144 - root_mean_squared_error: 0.1198 - val_loss: 0.7887 - val_root_mean_squared_error: 0.8881
# Epoch 456/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0166 - root_mean_squared_error: 0.1281 - val_loss: 0.7399 - val_root_mean_squared_error: 0.8602
# Epoch 457/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.7215 - val_root_mean_squared_error: 0.8494
# Epoch 458/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.7558 - val_root_mean_squared_error: 0.8693
# Epoch 459/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.7002 - val_root_mean_squared_error: 0.8368
# Epoch 460/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.7145 - val_root_mean_squared_error: 0.8453
# Epoch 461/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0160 - root_mean_squared_error: 0.1263 - val_loss: 0.7442 - val_root_mean_squared_error: 0.8627
# Epoch 462/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0154 - root_mean_squared_error: 0.1238 - val_loss: 0.7079 - val_root_mean_squared_error: 0.8413
# Epoch 463/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239 - val_loss: 0.7719 - val_root_mean_squared_error: 0.8786
# Epoch 464/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - val_loss: 0.7326 - val_root_mean_squared_error: 0.8559
# Epoch 465/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0186 - root_mean_squared_error: 0.1360 - val_loss: 0.6866 - val_root_mean_squared_error: 0.8286
# Epoch 466/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1339 - val_loss: 0.7423 - val_root_mean_squared_error: 0.8615
# Epoch 467/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.7109 - val_root_mean_squared_error: 0.8432
# Epoch 468/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - val_loss: 0.7254 - val_root_mean_squared_error: 0.8517
# Epoch 469/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0169 - root_mean_squared_error: 0.1297 - val_loss: 0.6932 - val_root_mean_squared_error: 0.8326
# Epoch 470/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.7025 - val_root_mean_squared_error: 0.8381
# Epoch 471/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0167 - root_mean_squared_error: 0.1290 - val_loss: 0.7022 - val_root_mean_squared_error: 0.8380
# Epoch 472/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0170 - root_mean_squared_error: 0.1293 - val_loss: 0.7085 - val_root_mean_squared_error: 0.8417
# Epoch 473/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0154 - root_mean_squared_error: 0.1238 - val_loss: 0.6939 - val_root_mean_squared_error: 0.8330
# Epoch 474/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.7177 - val_root_mean_squared_error: 0.8472
# Epoch 475/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242 - val_loss: 0.6862 - val_root_mean_squared_error: 0.8284
# Epoch 476/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0171 - root_mean_squared_error: 0.1307 - val_loss: 0.6633 - val_root_mean_squared_error: 0.8144
# Epoch 477/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1339 - val_loss: 0.7048 - val_root_mean_squared_error: 0.8395
# Epoch 478/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0163 - root_mean_squared_error: 0.1275 - val_loss: 0.7230 - val_root_mean_squared_error: 0.8503
# Epoch 479/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.6933 - val_root_mean_squared_error: 0.8327
# Epoch 480/480
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0180 - root_mean_squared_error: 0.1320 - val_loss: 0.7329 - val_root_mean_squared_error: 0.8561

# %%
loss, rmse = model1.evaluate(x_test, y_test, verbose=1)

print("Loss:", loss)
print("RMSE:", rmse)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4111 - root_mean_squared_error: 0.5842
# Loss: 0.7329423427581787
# RMSE: 0.8561205267906189

# %%
history_df = pd.DataFrame(history.history)

# Set the plot style
plt.style.use("ggplot")

# Create the plot
plt.figure(figsize=(12, 10))

# Plot the relevant metrics
plt.plot(history_df['loss'], label='Training Loss')
plt.plot(history_df['val_loss'], label='Validation Loss')

# Set the y-axis limits to focus on the range 0-1
plt.ylim(0, 5)

# Add titles and labels
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.grid()

# Show the plot
plt.show()

# %%
# prediction = (model1.predict(x_test)).reshape(-1)
# original = y_test

# print(prediction.shape)
# print(original.shape)

pred = model1.predict(x_test)
pred = scaler.inverse_transform(pred)
actual = scaler.inverse_transform(y_test)

# pred = pred.reshape(-1)
# actual = y_test_rescaled.reshape(-1)

# print(pred.shape)
# print(actual.shape)

print(actual.shape)
print(pred.shape)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# (428, 5)
# (428, 5)

# %%
# train_result = pd.DataFrame(data={'Prediction':pred, 'Actual':actual})
# train_result

# Mengubah actual dan pred menjadi DataFrame
actual_df = pd.DataFrame(actual, columns=[f'Real Value {i+1}' for i in range(actual.shape[1])])
predictions_df = pd.DataFrame(pred, columns=[f'Prediction {i+1}' for i in range(pred.shape[1])])

pred =  predictions_df.iloc[:, 0]
actual = actual_df.iloc[:, 0]

comparison_df = pd.DataFrame({
    'Real Values': actual,  # Ambil kolom pertama dari actual
    'Predictions': pred  # Ambil kolom pertama dari pred
})

# Memeriksa hasil
print(comparison_df)
# Out:
#      Real Values   Predictions
# 0        14360.0  14387.780273
# 1        14362.0  14387.827148
# 2        14343.0  14387.899414
# 3        14353.0  14386.491211
# 4        14335.0  14386.151367
# ..           ...           ...
# 423      15467.0  14814.071289
# 424      15407.0  14807.904297
# 425      15425.0  14792.759766
# 426      15415.0  14786.867188
# 427      15395.0  14783.859375
#
# [428 rows x 2 columns]

# %%
plt.figure(figsize=(14, 8))
plt.plot(actual, color = 'red', label = 'Real Rate')
plt.plot(pred, color = 'blue', label = 'Predicted Rate')
plt.title('Exchange Rate USD IDR Prediction 2015-2023')
plt.xlabel('Time')
plt.ylabel('Exchange Rate')
plt.legend()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.scatterplot(x=np.ravel(pred), y=actual, alpha=0.6)
plt.plot([actual.min(), actual.max()], [actual.min(), actual.max()], 'r--', lw=2)
plt.title("Scatter Plot of Actual Values vs Predictions")
plt.xlabel("Predictions")
plt.ylabel("Actual Values")
plt.xlim([actual.min(), actual.max()])
plt.ylim([actual.min(), actual.max()])
plt.grid(True)
plt.show()
